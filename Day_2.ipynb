# %% [markdown]
# <a href="https://colab.research.google.com/github/faudhim5-buddy/belajar-ai-30-hari/blob/main/Day_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nama = "Fauzan Adhima"
umur = 20
tinggi = 1.68
suka_ai = True

print(nama)
print(umur)
print(tinggi)
print(suka_ai)
# Out:
# Fauzan Adhima
# 20
# 1.68
# True

# %%
angka1 = 10
angka2 = 3

print(angka1 + angka2)
print(angka1 - angka2)
print(angka1 * angka2)
print(angka1 / angka2)
# Out:
# 13
# 7
# 30
# 3.3333333333333335

# %%
buah = ["apel", "mangga", "jeruk"]

print(buah)
print(buah[1])
print(len(buah))
# Out:
# ['apel', 'mangga', 'jeruk']
# mangga
# 3
