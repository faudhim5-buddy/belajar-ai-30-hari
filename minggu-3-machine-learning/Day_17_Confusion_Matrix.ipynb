# %% [markdown]
# <a href="https://colab.research.google.com/github/faudhim5-buddy/belajar-ai-30-hari/blob/main/Day_17_Confusion_Matrix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.metrics import confusion_matrix
import numpy as np

label_asli = ["sakit", "sakit", "sehat", "sakit", "sehat",
              "sehat", "sakit", "sehat", "sehat", "sakit",]
label_prediksi = ["sakit", "sehat", "sehat", "sakit", "sehat",
                 "sakit", "sakit", "sehat", "sehat", "sehat",]

cm = confusion_matrix(label_asli, label_prediksi, labels=["sakit", "sehat"])

print("Confusion Matrix")
print(cm)
print()
print("Format baca")
print("[[True Positive False Negative]")
print("[False Positive True Negative]]")
# Out:
# Confusion Matrix
# [[3 2]
#  [1 4]]
#
# Format baca
# [[True Positive False Negative]
# [False Positive True Negative]]

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

label_asli = ["sakit", "sakit", "sehat", "sakit", "sehat",
              "sehat", "sakit", "sehat", "sehat", "sakit",]
label_prediksi = ["sakit", "sehat", "sehat", "sakit", "sehat",
                 "sakit", "sakit", "sehat", "sehat", "sehat",]

cm = confusion_matrix(label_asli, label_prediksi, labels=["sakit", "sehat"])
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["sakit", "sehat"])
disp.plot()
plt.title("Confusion Matrix Deteksi Penyakit")
plt.show()
print()
print(classification_report(label_asli, label_prediksi))
# Out:
#               precision    recall  f1-score   support
#
#        sakit       0.75      0.60      0.67         5
#        sehat       0.67      0.80      0.73         5
#
#     accuracy                           0.70        10
#    macro avg       0.71      0.70      0.70        10
# weighted avg       0.71      0.70      0.70        10

# %%
from sklearn.metrics import classification_report, accuracy_score

label_asli = ["sehat"] *950 + ["sakit"] *50
label_prediksi_bodoh = ["sehat"] *1000

print("Akurasi Bodoh", accuracy_score(label_asli, label_prediksi_bodoh) *100, "%")
print()
print("Laporan Detail")
print(classification_report(label_asli, label_prediksi_bodoh))
# Out:
# Akurasi Bodoh 95.0 %
#
# Laporan Detail
#               precision    recall  f1-score   support
#
#        sakit       0.00      0.00      0.00        50
#        sehat       0.95      1.00      0.97       950
#
#     accuracy                           0.95      1000
#    macro avg       0.47      0.50      0.49      1000
# weighted avg       0.90      0.95      0.93      1000
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...
