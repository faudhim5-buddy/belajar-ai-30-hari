# %% [markdown]
# <a href="https://colab.research.google.com/github/faudhim5-buddy/belajar-ai-30-hari/blob/main/Day_5_Fungsi_argument_%26_return.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def sapa():
  print("Halo aku belajar AI!")

sapa()
sapa()
# Out:
# Halo aku belajar AI!
# Halo aku belajar AI!

# %%
from os import supports_follow_symlinks
def sapa_nama(nama):
  print("halo", nama,"!", "Perjalananmu masih panjang! Ini baru hari ke 5")

sapa_nama("Buddy")
sapa_nama("Sonya")
sapa_nama("Jiya")
# Out:
# halo Buddy ! Perjalananmu masih panjang! Ini baru hari ke 5
# halo Sonya ! Perjalananmu masih panjang! Ini baru hari ke 5
# halo Jiya ! Perjalananmu masih panjang! Ini baru hari ke 5

# %%
def hitungan_luas(panjang, lebar):
  luas = panjang * lebar
  return luas

hasil = hitungan_luas(115, 46)
print("Luas lahan adalah", hasil)

print("Luas lahan adalah", hitungan_luas(89,37))
# Out:
# Luas lahan adalah 5290
# Luas lahan adalah 3293

# %%
def cek_kelulusan(nilai):
  if nilai >= 50:
    return "Najah"
  else:
    return "Rosib"

print(cek_kelulusan(90))
print(cek_kelulusan(40))
print(cek_kelulusan(51))
# Out:
# Najah
# Rosib
# Najah

# %%
def hitung_pake_print(panjang,lebar):
  print(panjang * lebar)

hasil = hitung_pake_print(5,8)
print("Nilai hasil",hasil)
# Out:
# 40
# Nilai hasil None

# %%
def hitung_pake_return(panjang,lebar):
  return panjang * lebar

hasil = hitung_pake_return(9,5)
print("ini tanah luas",hasil)
print("Tanahnya ada 2 maka", hasil * 2)
# Out:
# ini tanah luas 45
# Tanahnya ada 2 maka 90

# %%
def cek_kelulusan(nilai):
  if nilai >= 50:
    return "najah"
  else:
    return "rosib"

daftar_nilai = [80,95,64,43,25,39,75,55]

for nilai in daftar_nilai:
  status = cek_kelulusan(nilai)
  print("Nilai", nilai, "maka", status)
# Out:
# Nilai 80 maka najah
# Nilai 95 maka najah
# Nilai 64 maka najah
# Nilai 43 maka rosib
# Nilai 25 maka rosib
# Nilai 39 maka rosib
# Nilai 75 maka najah
# Nilai 55 maka najah
