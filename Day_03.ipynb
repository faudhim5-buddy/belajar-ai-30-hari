# %% [markdown]
# <a href="https://colab.research.google.com/github/faudhim5-buddy/belajar-ai-30-hari/blob/main/Day_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nama = "Adhima"
kalimat = "Aku sedang belajar AI"

print(nama)
print(kalimat)
print(len(kalimat))
print(kalimat.upper())
print(kalimat.replace("AI", "Machine Learning"))
# Out:
# Adhima
# Aku sedang belajar AI
# 21
# AKU SEDANG BELAJAR AI
# Aku sedang belajar Machine Learning

# %%
umur = 25
tinggi = 1.68

print(umur + 5)
print(tinggi * 2)
print(type(umur))
print(type(tinggi))
# Out:
# 30
# 3.36
# <class 'int'>
# <class 'float'>

# %%
suka_kopi = True
suka_suki = False

print(suka_kopi)
print(type(suka_kopi))
print(suka_kopi and suka_suki)
print(suka_kopi or suka_suki)
# Out:
# True
# <class 'bool'>
# False
# True
